# %% [markdown]
# # Comparing correlation matrices of the tabularized violation data

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

csv_file = "./csv/study.csv"
violation_list_file = "./json/violation_list.json"

# read study.csv
study_df = pd.read_csv(csv_file, index_col=0)

# read violation_list.json
with open(violation_list_file, 'r') as f:
    violation_columns = json.load(f)

view_df = study_df[violation_columns] # view of study dataframe with only violation columns
view_df.head()

# # Compute the correlation matrix
# correlation_matrix = view_df.corr()

# # Plot the correlation matrix
# plt.figure(figsize=(4,4))
# plt.matshow(correlation_matrix, cmap='coolwarm', fignum=1)
# plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=90)
# plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
# plt.colorbar()
# plt.show()
# Out:
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasStudyType  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-isPreparedByLibrary  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                2.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-isSequencedForTherapeuticArea  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/248e9792-8549-4e0d-8665-06c42aff8ffc  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                1.0
#
#                                                     http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-hasStrandedness  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                2.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-isMeasuredOnPlatform  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/afb51f95-5b17-45a4-b62d-c58f4998f930  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-isSequencedForIndication  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasContactCompBio  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/38c0a1c7-1c92-489a-a22e-87f5335ccb1a  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                1.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/9589ebf0-6f4f-4b80-9a5a-75aa25b5715f  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                2.0
#
#                                                     http://data.boehringer.com/ontology/omics/ece15faa-30b3-471c-ae51-2d6d1f80e3a9  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                2.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                1.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                1.0
#
#                                                     http://data.boehringer.com/ontology/omics/0c2600b5-30b2-40c7-917a-b402e73f55ae  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                1.0
#
#                                                     http://data.boehringer.com/ontology/omics/af998a22-f11b-43ea-b0ac-44e728baeafb  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-hasSequencingProtocol  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasContactScientist  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-isPartOfProject  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasResponsibleSite
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

csv_file = "./csv/ex51_violations_metadata.csv"
violation_list_file = "./json/violation_list.json"

# read study.csv
study_df = pd.read_csv(csv_file, index_col=0)

# read violation_list.json
with open(violation_list_file, 'r') as f:
    violation_columns = json.load(f)

view_df = study_df[violation_columns] # view of study dataframe with only violation columns
view_df.describe()

# # Compute the correlation matrix
# correlation_matrix = view_df.corr()

# # Plot the correlation matrix
# plt.figure(figsize=(4,4))
# plt.matshow(correlation_matrix, cmap='coolwarm', fignum=1)
# plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=90)
# plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
# plt.colorbar()
# plt.show()
# Out:
#        http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasStudyType  \
# count                                        5203.000000
# mean                                            0.000384
# std                                             0.019604
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-isPreparedByLibrary  \
# count                                        5203.000000
# mean                                            0.498366
# std                                             0.500045
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/OmicsStudyShape-isSequencedForTherapeuticArea  \
# count                                        5203.000000
# mean                                            0.000384
# std                                             0.019604
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/248e9792-8549-4e0d-8665-06c42aff8ffc  \
# count                                        5203.000000
# mean                                            0.405151
# std                                             0.490968
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-hasStrandedness  \
# count                                        5203.000000
# mean                                            0.498366
# std                                             0.500045
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-isMeasuredOnPlatform  \
# count                                        5203.000000
# mean                                            0.498366
# std                                             0.500045
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/afb51f95-5b17-45a4-b62d-c58f4998f930  \
# count                                        5203.000000
# mean                                            0.096098
# std                                             0.294754
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/OmicsStudyShape-isSequencedForIndication  \
# count                                        5203.000000
# mean                                            0.000384
# std                                             0.019604
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasContactCompBio  \
# count                                        5203.000000
# mean                                            0.000384
# std                                             0.019604
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/38c0a1c7-1c92-489a-a22e-87f5335ccb1a  \
# count                                        5203.000000
# mean                                            0.405151
# std                                             0.490968
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/9589ebf0-6f4f-4b80-9a5a-75aa25b5715f  \
# count                                        5203.000000
# mean                                            0.405151
# std                                             0.490968
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/ece15faa-30b3-471c-ae51-2d6d1f80e3a9  \
# count                                        5203.000000
# mean                                            0.498366
# std                                             0.500045
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/0c2600b5-30b2-40c7-917a-b402e73f55ae  \
# count                                        5203.000000
# mean                                            0.405151
# std                                             0.490968
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/af998a22-f11b-43ea-b0ac-44e728baeafb  \
# count                                        5203.000000
# mean                                            0.156833
# std                                             0.363678
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-hasSequencingProtocol  \
# count                                        5203.000000
# mean                                            0.498366
# std                                             0.500045
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasContactScientist  \
# count                                        5203.000000
# mean                                            0.000384
# std                                             0.019604
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/OmicsStudyShape-isPartOfProject  \
# count                                        5203.000000
# mean                                            0.000384
# std                                             0.019604
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasResponsibleSite
# count                                        5203.000000
# mean                                            0.000384
# std                                             0.019604
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

csv_file_new = "./csv/study.csv"
csv_file_old = "./csv/ex51_violations_metadata.csv"
violation_list_file = "./json/violation_list.json"

# read study.csv
study_df_new = pd.read_csv(csv_file_new, index_col=0)

# read ex51_violations_metadata.csv
study_df_old = pd.read_csv(csv_file_old, index_col=0)

# read violation_list.json
with open(violation_list_file, 'r') as f:
    violation_columns = json.load(f)

view_df_new = study_df_new[violation_columns]
view_df_old = study_df_old[violation_columns]

view_df_new.head()
# Out:
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasStudyType  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-isPreparedByLibrary  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                2.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-isSequencedForTherapeuticArea  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/248e9792-8549-4e0d-8665-06c42aff8ffc  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                1.0
#
#                                                     http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-hasStrandedness  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                2.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-isMeasuredOnPlatform  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/afb51f95-5b17-45a4-b62d-c58f4998f930  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-isSequencedForIndication  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasContactCompBio  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/38c0a1c7-1c92-489a-a22e-87f5335ccb1a  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                1.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/9589ebf0-6f4f-4b80-9a5a-75aa25b5715f  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                2.0
#
#                                                     http://data.boehringer.com/ontology/omics/ece15faa-30b3-471c-ae51-2d6d1f80e3a9  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                2.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                1.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                1.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                1.0
#
#                                                     http://data.boehringer.com/ontology/omics/0c2600b5-30b2-40c7-917a-b402e73f55ae  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                1.0
#
#                                                     http://data.boehringer.com/ontology/omics/af998a22-f11b-43ea-b0ac-44e728baeafb  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/TranscriptOmicsSampleShape-hasSequencingProtocol  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasContactScientist  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-isPartOfProject  \
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
#
#                                                     http://data.boehringer.com/ontology/omics/OmicsStudyShape-hasResponsibleSite
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0
# http://data.boehringer.com/uuid/TranscriptOmics...                                                0.0
# http://data.boehringer.com/uuid/PrimaryCellSpec...                                                0.0

# %%
view_df_old.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Work\ICG\BI\bikg_app\bikg_app\compare_violation_correlation.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Work/ICG/BI/bikg_app/bikg_app/compare_violation_correlation.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> view_df_old[x]
#
# NameError: name 'x' is not defined
